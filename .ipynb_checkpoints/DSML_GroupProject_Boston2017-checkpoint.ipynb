# %% [markdown]
# # `Group Project` - Boston 2017 Bike Sharing Analysis

# %% [markdown]
# ## Introduction
# In this project we will work with real world data from "Blue Bikes" which is a bike sharing firm based in Boston.
#
# Our focus lies on data of the year 2017 and we will make a comprehensive analysis, in which we use typical data analysis and machine learning approaches to make use of the data to monitize and optimize the operations of "Blue Bikes". The overall topic is smart mobility systems and how we can use data in impactful ways to address pressing societal issues. In terms of bike sharing the addressed societal issue are the reduce of greenhouse gas emissions, reduce of pollution as health risk for urban population, reduce of (fatal) road accidents and to create a more efficient road transport infrastructur. We will cover the following task:
#
# - **Task 1) Data Collection & Preparation**:
#     * Cleaning of datasets for use in later analysis stages
# - **Task 2) Descriptive Analysis**:
#     * Demonstrate temporal demand patterns and seasonality
#     * Demonstrate geographical demand patterns
#     * Define Key Performance Indicators which provides overview of current fleet operations
# - **Task 3) Predictive Analysis**:
#     * Forecast total system-level demand in the next hour
#
# **The authors of this analysis are:**
# * Robin Kirch      (7364580)
# * Niklas Nesseler  (7367375)
# * Lukas Tempfli    (7367097)
# * Pascal Zajonz    (7369974)
# * Sven Dornbrach   (7364484)
# * Moritz Danhausen (7369413)
#
#
# Hint: Please run the seperated cells from the top to the bottom

# %% [markdown]
# ### Required Imports

# %%
import numpy as np
import pandas as pd
from datetime import date, time, datetime, timedelta 
import matplotlib.pyplot as plt
import folium
from folium import plugins
from folium.plugins import HeatMap
from datetime import datetime 
from datetime import timedelta 
import math
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns
sns.set()
sns.set_style("white")
sns.set_palette("GnBu_d")
#import etc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-32-28a071ece508> in <module>
#       3 from datetime import date, time, datetime, timedelta
#       4 import matplotlib.pyplot as plt
# ----> 5 import folium
#       6 from folium import plugins
#       7 from folium.plugins import HeatMap
#
# ModuleNotFoundError: No module named 'folium'

# %% [markdown]
# # `Task 1) Data Collection & Preparation:`

# %% [markdown]
# ### Details to Task 1
# #TODO
# Detailed introduction to task 1 here

# %%
raw_data_boston = pd.read_csv("boston_2017.csv")
#Problematisch bei gleicher Startzeit und ggbf. kompletten Dateipfad angeben notwendig

# %%
raw_data_boston["start_time"]=pd.to_datetime(raw_data_boston["start_time"])
raw_data_boston["end_time"]=pd.to_datetime(raw_data_boston["end_time"])
raw_data_boston
# Out:
#                  start_time            end_time  start_station_id  \
# 0       2017-01-01 00:06:58 2017-01-01 00:12:49                67
# 1       2017-01-01 00:13:16 2017-01-01 00:28:07                36
# 2       2017-01-01 00:16:17 2017-01-01 00:44:10                36
# 3       2017-01-01 00:21:22 2017-01-01 00:33:50                46
# 4       2017-01-01 00:30:06 2017-01-01 00:40:28                10
# ...                     ...                 ...               ...
# 1313769 2017-12-31 23:46:18 2017-12-31 23:50:27               117
# 1313770 2017-12-29 16:11:56 2017-12-29 16:16:18                54
# 1313771 2017-12-30 08:09:44 2017-12-30 08:26:08                54
# 1313772 2017-12-30 12:20:01 2017-12-30 12:49:12                54
# 1313773 2017-12-30 18:27:39 2017-12-30 18:53:54                54
#
#          end_station_id                        start_station_name  \
# 0                   139              MIT at Mass Ave / Amherst St
# 1                    10  Boston Public Library - 700 Boylston St.
# 2                     9  Boston Public Library - 700 Boylston St.
# 3                    19                   Christian Science Plaza
# 4                     8             B.U. Central - 725 Comm. Ave.
# ...                 ...                                       ...
# 1313769             141                      Binney St / Sixth St
# 1313770              42                     Tremont St at West St
# 1313771              58                     Tremont St at West St
# 1313772              46                     Tremont St at West St
# 1313773              21                     Tremont St at West St
#
#                                           end_station_name  bike_id  \
# 0                                                Dana Park      644
# 1                            B.U. Central - 725 Comm. Ave.      230
# 2                            Agganis Arena - 925 Comm Ave.      980
# 3                                  Buswell St. at Park Dr.     1834
# 4            Union Square - Brighton Ave. at Cambridge St.      230
# ...                                                    ...      ...
# 1313769                                     Kendall Street     1846
# 1313770  Boylston St at Arlington St TEMPORARY WINTER L...        2
# 1313771                          Beacon St at Arlington St     1534
# 1313772  Christian Science Plaza - Massachusetts Ave at...     1978
# 1313773                   Prudential Center - Belvedere St       15
#
#           user_type
# 0        Subscriber
# 1        Subscriber
# 2          Customer
# 3        Subscriber
# 4        Subscriber
# ...             ...
# 1313769  Subscriber
# 1313770  Subscriber
# 1313771  Subscriber
# 1313772  Subscriber
# 1313773  Subscriber
#
# [1313774 rows x 8 columns]

# %%
raw_data_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313774 entries, 0 to 1313773
# Data columns (total 8 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   start_time          1313774 non-null  datetime64[ns]
#  1   end_time            1313774 non-null  datetime64[ns]
#  2   start_station_id    1313774 non-null  int64
#  3   end_station_id      1313774 non-null  int64
#  4   start_station_name  1313774 non-null  object
#  5   end_station_name    1313774 non-null  object
#  6   bike_id             1313774 non-null  int64
#  7   user_type           1313774 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(3)
# memory usage: 80.2+ MB

# %%
raw_data_boston.describe()
# Out:
#        start_station_id  end_station_id       bike_id
# count      1.313774e+06    1.313774e+06  1.313774e+06
# mean       8.571053e+01    8.554360e+01  9.931371e+02
# std        5.634766e+01    5.648317e+01  5.701397e+02
# min        1.000000e+00    1.000000e+00  1.000000e+00
# 25%        4.300000e+01    4.300000e+01  5.160000e+02
# 50%        7.400000e+01    7.400000e+01  9.780000e+02
# 75%        1.170000e+02    1.170000e+02  1.512000e+03
# max        2.320000e+02    2.320000e+02  1.981000e+03

# %%
raw_data_boston.columns
# Out:
# Index(['start_time', 'end_time', 'start_station_id', 'end_station_id',
#        'start_station_name', 'end_station_name', 'bike_id', 'user_type'],
#       dtype='object')

# %%
raw_data_boston["end_time"].describe()
#start_time nicht zugreifbar
# Out:
# <ipython-input-35-0a5c0f10cd4b>:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   raw_data_boston["end_time"].describe()
# count                 1313774
# unique                1245112
# top       2017-08-15 17:37:49
# freq                        6
# first     2017-01-01 00:12:49
# last      2018-01-07 20:00:16
# Name: end_time, dtype: object

# %%
raw_data_boston["start_station_id"].describe()
# Out:
# count    1.313774e+06
# mean     8.571053e+01
# std      5.634766e+01
# min      1.000000e+00
# 25%      4.300000e+01
# 50%      7.400000e+01
# 75%      1.170000e+02
# max      2.320000e+02
# Name: start_station_id, dtype: float64

# %%
raw_data_boston["end_station_id"].describe()
# Out:
# count    1.313774e+06
# mean     8.554360e+01
# std      5.648317e+01
# min      1.000000e+00
# 25%      4.300000e+01
# 50%      7.400000e+01
# 75%      1.170000e+02
# max      2.320000e+02
# Name: end_station_id, dtype: float64

# %%
raw_data_boston["start_station_name"].describe()
# Out:
# count                          1313774
# unique                             285
# top       MIT at Mass Ave / Amherst St
# freq                             42320
# Name: start_station_name, dtype: object

# %%
raw_data_boston["end_station_name"].describe()
# Out:
# count                          1313774
# unique                             283
# top       MIT at Mass Ave / Amherst St
# freq                             42442
# Name: end_station_name, dtype: object

# %%
raw_data_boston["bike_id"].describe()
# Out:
# count    1.313774e+06
# mean     9.931371e+02
# std      5.701397e+02
# min      1.000000e+00
# 25%      5.160000e+02
# 50%      9.780000e+02
# 75%      1.512000e+03
# max      1.981000e+03
# Name: bike_id, dtype: float64

# %%
raw_data_boston["user_type"].describe()
# Out:
# count        1313774
# unique             2
# top       Subscriber
# freq         1104738
# Name: user_type, dtype: object

# %%
raw_data_boston.count()
# Out:
# start_time            1313774
# end_time              1313774
# start_station_id      1313774
# end_station_id        1313774
# start_station_name    1313774
# end_station_name      1313774
# bike_id               1313774
# user_type             1313774
# dtype: int64

# %%
raw_data_weather= pd.read_csv("weather_hourly_boston.csv")
raw_data_weather["date_time"]=pd.to_datetime(raw_data_weather["date_time"])

# %%
raw_data_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43848 entries, 0 to 43847
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date_time  43354 non-null  datetime64[ns]
#  1   max_temp   43354 non-null  float64
#  2   min_temp   43354 non-null  float64
#  3   precip     43356 non-null  float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.3 MB

# %%
raw_data_weather.head(20)
# Out:
#              date_time  max_temp  min_temp  precip
# 0  2015-01-02 01:00:00      -1.1      -1.1     0.0
# 1  2015-01-02 02:00:00      -1.1      -1.1     0.0
# 2  2015-01-02 03:00:00      -0.6      -0.6     0.0
# 3  2015-01-02 04:00:00      -0.6      -0.6     0.0
# 4  2015-01-02 05:00:00      -0.6      -0.6     0.0
# 5  2015-01-01 06:00:00      -5.6      -5.6     0.0
# 6  2015-01-01 07:00:00      -5.6      -5.6     0.0
# 7  2015-01-01 08:00:00      -5.6      -5.6     0.0
# 8  2015-01-01 09:00:00      -4.4      -4.4     0.0
# 9  2015-01-01 10:00:00      -5.6      -5.6     0.0
# 10 2015-01-01 11:00:00      -5.0      -5.0     0.0
# 11 2015-01-01 12:00:00      -5.0      -5.0     0.0
# 12 2015-01-01 13:00:00      -5.6      -5.6     0.0
# 13 2015-01-01 14:00:00      -3.9      -3.9     0.0
# 14 2015-01-01 15:00:00      -2.2      -2.2     0.0
# 15 2015-01-01 16:00:00      -1.1      -1.1     0.0
# 16 2015-01-01 17:00:00      -0.6      -0.6     0.0
# 17 2015-01-01 18:00:00       0.0       0.0     0.0
# 18 2015-01-01 19:00:00       0.6       0.6     0.0
# 19 2015-01-01 20:00:00       0.6       0.6     0.0

# %%
first_date =datetime(year=2017,day=1,month=1)
lastdate=datetime(year=2017, day=31,month =12)

neu_weather_2017= raw_data_weather[(raw_data_weather["date_time"]>=first_date)&(raw_data_weather["date_time"]<=lastdate)]
neu_weather_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 
# 49                  Nashua Street at Red Auerbach Way
#
#                                      end_station_name  bike_id   user_type  \
# 0                                           Dana Park      644  Subscriber
# 1                       B.U. Central - 725 Comm. Ave.      230  Subscriber
# 2                       Agganis Arena - 925 Comm Ave.      980    Customer
# 3                             Buswell St. at Park Dr.     1834  Subscriber
# 4       Union Square - Brighton Ave. at Cambridge St.      230  Subscriber
# 5           Brian P. Murphy Staircase at Child Street     1918  Subscriber
# 6                                       MIT Vassar St     1102  Subscriber
# 7                                       MIT Vassar St     1060  Subscriber
# 8                               Kenmore Sq / Comm Ave     1613  Subscriber
# 9   Harvard Real Estate - Brighton Mills - 370 Wes...      980    Customer
# 10  Central Sq Post Office / Cambridge City Hall a...     1550  Subscriber
# 11            Powder House Circle - Nathan Tufts Park      379    Customer
# 12                        Curtis Hall at South Street       52  Subscriber
# 13                                      Dudley Square      375  Subscriber
# 14                    MIT Pacific St at Purrington St     1094  Subscriber
# 15                         Rowes Wharf - Atlantic Ave      740  Subscriber
# 16     Packard's Corner - Comm. Ave. at Brighton Ave.      719    Customer
# 17                       MIT at Mass Ave / Amherst St      972  Subscriber
# 18                       Back Bay / South End Station      106  Subscriber
# 19                       Back Bay / South End Station     1487  Subscriber
# 20     Edwards Playground - Main Street & Eden Street      327  Subscriber
# 21                            Christian Science Plaza     1615  Subscriber
# 22                    Rindge Avenue - O'Neill Library     1215  Subscriber
# 23                                      Day Boulevard      789  Subscriber
# 24                    MIT Pacific St at Purrington St      972  Subscriber
# 25                           Cambridge St. at Joy St.     1282    Customer
# 26                       MIT at Mass Ave / Amherst St      532  Subscriber
# 27                  Nashua Street at Red Auerbach Way     1087  Subscriber
# 28        The Esplanade - Beacon St. at Arlington St.     1613  Subscriber
# 29  CambridgeSide Galleria - CambridgeSide PL at L...      875    Customer
# 30  CambridgeSide Galleria - CambridgeSide PL at L...     1439    Customer
# 31                        Tremont St. at Berkeley St.      416  Subscriber
# 32                           Roxbury Crossing Station      312  Subscriber
# 33                  South Station - 700 Atlantic Ave.       34  Subscriber
# 34                 Mayor Martin J Walsh - 28 State St     1094  Subscriber
# 35                            Christian Science Plaza      154  Subscriber
# 36                      Jackson Square T at Centre St      312  Subscriber
# 37   HMS / HSPH - Ave. Louis Pasteur at Longwood Ave.      964  Subscriber
# 38                                      Day Boulevard     1094  Subscriber
# 39                           Longwood Ave / Binney St     1141  Subscriber
# 40        Cambridge St - at Columbia St / Webster Ave     1596  Subscriber
# 41           Boston Public Library - 700 Boylston St.      317  Subscriber
# 42                        Columbus Ave. at Mass. Ave.     1316  Subscriber
# 43                       Brigham Cir / Huntington Ave      312  Subscriber
# 44          Linear Park - Mass. Ave. at Cameron Ave.      1671  Subscriber
# 45              Central Square at Mass Ave / Essex St     1094  Subscriber
# 46                       MIT at Mass Ave / Amherst St     1899  Subscriber
# 47                           Roxbury Crossing Station      312  Subscriber
# 48  Central Sq Post Office / Cambridge City Hall a...      497  Subscriber
# 49              Central Square at Mass Ave / Essex St     1402  Subscriber
#
#           Date  Rented
# 0   2017-01-01       1
# 1   2017-01-01       1
# 2   2017-01-01       1
# 3   2017-01-01       1
# 4   2017-01-01       1
# 5   2017-01-01       1
# 6   2017-01-01       1
# 7   2017-01-01       1
# 8   2017-01-01       1
# 9   2017-01-01       1
# 10  2017-01-01       1
# 11  2017-01-01       1
# 12  2017-01-01       1
# 13  2017-01-01       1
# 14  2017-01-01       1
# 15  2017-01-01       1
# 16  2017-01-01       1
# 17  2017-01-01       1
# 18  2017-01-01       1
# 19  2017-01-01       1
# 20  2017-01-01       1
# 21  2017-01-01       1
# 22  2017-01-01       1
# 23  2017-01-01       1
# 24  2017-01-01       1
# 25  2017-01-01       1
# 26  2017-01-01       1
# 27  2017-01-01       1
# 28  2017-01-01       1
# 29  2017-01-01       1
# 30  2017-01-01       1
# 31  2017-01-01       1
# 32  2017-01-01       1
# 33  2017-01-01       1
# 34  2017-01-01       1
# 35  2017-01-01       1
# 36  2017-01-01       1
# 37  2017-01-01       1
# 38  2017-01-01       1
# 39  2017-01-01       1
# 40  2017-01-01       1
# 41  2017-01-01       1
# 42  2017-01-01       1
# 43  2017-01-01       1
# 44  2017-01-01       1
# 45  2017-01-01       1
# 46  2017-01-01       1
# 47  2017-01-01       1
# 48  2017-01-01       1
# 49  2017-01-01       1

# %%
bikes_rented_total = raw_data_boston.groupby("Date")["Rented"].sum()
fig,ax = plt.subplots(figsize=(16,9)) 

ax.plot(bikes_rented_total)

ax.set_title("# rentals per day")
ax.set_ylabel("# of rentals")
ax.set_xlabel("Date")

plt.show()

# %% [markdown]
# Plot für die Anzahl der ausgeliehenen Fahrräder in Relation zu der Temperatur (Lukas)

# %%
#connecting both data sets by  the date with an inner join

left=raw_data_boston
right=neu_weather_2017


inner_merge = pd.merge(left=left, right=right, left_on="start_time", right_on="date_time")

inner_merge
# Out:
#              start_time            end_time  start_station_id  end_station_id  \
# 0   2017-01-01 03:00:00 2017-01-01 03:03:45                67             178
# 1   2017-01-01 12:00:00 2017-01-01 12:04:27               131              27
# 2   2017-01-11 14:00:00 2017-01-11 14:04:04               179              67
# 3   2017-01-20 18:00:00 2017-01-20 18:06:24                90              91
# 4   2017-01-23 11:00:00 2017-01-23 11:06:11               179              67
# ..                  ...                 ...               ...             ...
# 393 2017-12-16 23:00:00 2017-12-16 23:15:54                69              33
# 394 2017-12-18 22:00:00 2017-12-18 22:02:22               178             179
# 395 2017-12-19 08:00:00 2017-12-19 08:27:11               193              90
# 396 2017-12-20 17:00:00 2017-12-20 17:09:30               228              47
# 397 2017-12-21 08:00:00 2017-12-21 08:07:24                 6              22
#
#                                     start_station_name  \
# 0                         MIT at Mass Ave / Amherst St
# 1                        Jackson Square T at Centre St
# 2                                        MIT Vassar St
# 3          Lechmere Station at Cambridge St / First St
# 4                                        MIT Vassar St
# ..                                                 ...
# 393            Coolidge Corner - Beacon St @ Centre St
# 394                    MIT Pacific St at Purrington St
# 395  Brookline Village - Station Street @ MBTA TEMP...
# 396                                 One Memorial Drive
# 397                             Cambridge St at Joy St
#
#                                      end_station_name  bike_id   user_type  \
# 0                     MIT Pacific St at Purrington St      972  Subscriber
# 1                            Roxbury Crossing Station      310  Subscriber
# 2                        MIT at Mass Ave / Amherst St     1625  Subscriber
# 3    One Kendall Square at Hampshire St / Portland St     1665  Subscriber
# 4                        MIT at Mass Ave / Amherst St     1030  Subscriber
# ..                                                ...      ...         ...
# 393                                    Kenmore Square     1640  Subscriber
# 394                                     MIT Vassar St      158  Subscriber
# 395       Lechmere Station at Cambridge St / First St      743  Subscriber
# 396                            Cross St at Hanover St     1616  Subscriber
# 397                  South Station - 700 Atlantic Ave      277  Subscriber
#
#            Date  Rented           date_time  max_temp  min_temp  precip
# 0    2017-01-01       1 2017-01-01 03:00:00       5.0       5.0     1.0
# 1    2017-01-01       1 2017-01-01 12:00:00       2.2       2.2     0.0
# 2    2017-01-11       1 2017-01-11 14:00:00       8.9       8.9     0.0
# 3    2017-01-20       1 2017-01-20 18:00:00       3.9       3.9     0.0
# 4    2017-01-23       1 2017-01-23 11:00:00       2.2       2.2     1.0
# ..          ...     ...                 ...       ...       ...     ...
# 393  2017-12-16       1 2017-12-16 23:00:00      -1.1      -1.1     0.0
# 394  2017-12-18       1 2017-12-18 22:00:00       1.1       1.1     0.0
# 395  2017-12-19       1 2017-12-19 08:00:00       2.2       2.2     0.0
# 396  2017-12-20       1 2017-12-20 17:00:00       5.6       5.6     0.0
# 397  2017-12-21       1 2017-12-21 08:00:00      -1.7      -1.7     0.0
#
# [398 rows x 14 columns]

# %%
weather_rentals=inner_merge.groupby("min_temp")["Rented"].sum()

Fig_2, ax_2= plt.subplots(figsize=(16,9))

ax_2.plot(weather_rentals)

ax_2.set_title("temperature/rentals")
ax_2.set_ylabel("number of rentals")
ax_2.set_xlabel("temperature at the rental")

plt.show()

# %% [markdown]
# Plot für die Anzahl der ausgeliehenen Fahrräder an den jeweiligen Wochentag (Lukas)

# %%
#add the weekday to the data

raw_data_boston["Weekday"] = raw_data_boston["start_time"].apply(lambda ts: get_weekday (ts))

# %%
weekday_rentals=raw_data_boston.groupby("Weekday")["Rented"].sum()

Fig_3, ax_3= plt.subplots(figsize=(16,9))

ax_3.plot(weekday_rentals)

ax_3.set_title("weekday/rentals")
ax_3.set_ylabel("number of rentals")
ax_3.set_xlabel("weekday")


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Plot zur Beliebtheit einzelner Stationen (Lukas)

# %%
start_station_rentals=inner_merge.groupby("start_station_id")["Rented"].sum()
end_station_rentals=inner_merge.groupby("end_station_id")["Rented"].sum()


Fig_4, ax_4= plt.subplots(figsize=(16,9))

ax_4.plot(start_station_rentals, label="start_station")
ax_4.plot(end_station_rentals , label="end_station")

ax_4.set_title("popularity of a station")
ax_4.set_ylabel("number of rentals")
ax_4.set_xlabel("station number")

plt.legend(loc="upper left")

# %% [markdown]
# # `Task 2) Descriptive Analysis:`

# %% [markdown]
# ### Details to Task 2
# #TODO
# Detailed introduction to task 2 here

# %% [markdown]
# # `Task 3) Descriptive Analysis:`

# %% [markdown]
# ### Details to Task 3
# #TODO
# Detailed introduction to task 3 here
